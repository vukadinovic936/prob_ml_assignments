# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

N = 100 

x = np.random.rand(N,1) 
y = np.random.randn(N,1)

data = np.concatenate((x,y),axis=1)
data = data.reshape((N,2))

plt.scatter(x, y, color='b', marker='o')
plt.show()

# %%
#number of clusters
K = 6
# randomly initialize cluster "heads"
x_res = np.random.rand(K,1)
y_res = np.random.rand(K,1)
m = np.concatenate((x_res, y_res), axis=1)
m = m.reshape(K,2)
print(m)
colors = ['r','b','g','k','c','m','y']
for i in range(K):
    plt.scatter(x_res[i],y_res[i], color=colors[i],marker='o')
# Out:
# [[0.02546871 0.05247714]
#  [0.90807319 0.96642183]
#  [0.22213002 0.85132298]
#  [0.33124241 0.38243683]
#  [0.30974066 0.49910002]
#  [0.45731845 0.10608991]]

# %%
def dist(a,b):
    return np.sqrt((a[0]-b[0])**2 + (a[1]-b[1])**2)**2

# %%
# should have K elements each array
clusters = []

for i in range(K):
    clusters.append(np.array([]))
    
for p in data:
    dists = np.zeros(K)
    for idx,rp in enumerate(m):
        dists[idx] = dist(p,rp)
        
    clusters[np.argmin(dists)] = np.append(clusters[np.argmin(dists)],np.array(p))

clusters
# Out:
# [array([ 0.10013357, -1.32138892,  0.01457896, -0.9048243 ,  0.14531898,
#         -0.04914236,  0.01957337, -0.60505473,  0.13386966, -1.62731638,
#          0.10830424, -1.12040057,  0.09574925, -2.62879726,  0.05226932,
#         -0.72807786,  0.13726329, -0.91190289,  0.37074119, -1.20650751,
#          0.1170002 , -1.21653732,  0.23548565, -0.67387358,  0.01110748,
#          0.01742764,  0.01565319, -1.21350675,  0.28239738, -1.04475538,
#          0.22846323, -1.59405111,  0.21722869, -1.50798994,  0.1723979 ,
#         -1.23448595,  0.017265  , -1.12969867,  0.309966  , -0.54050917,
#          0.19321869, -0.33513532,  0.10167953, -0.04271584,  0.25476952,
#         -0.34544019]),
#  array([0.5892202 , 0.84059677, 0.99575697, 0.81497488, 0.89578488,
#         0.78402717, 0.45367006, 1.79442271, 0.84481807, 0.94341858,
#         0.95523127, 0.94541836, 0.96240187, 1.37838709, 0.88295122,
#         0.99194048, 0.76529076, 0.73135889, 0.85353129, 0.85996178,
#         0.81287998, 1.02399035, 0.79116297, 1.47097544, 0.66131836,
#         1.75410849, 0.94407275, 1.12272578, 0.85129914, 0.56323603,
#         0.98341967, 0.87548554]),
#  array([0.31502464, 1.69545803, 0.05842685, 1.31510356, 0.28905383,
#         1.25472036, 0.37876983, 1.92985499, 0.00416847, 2.18661603,
#         0.06811072, 1.37509183, 0.27083571, 0.98391139, 0.244989  ,
#         0.81707019, 0.42590698, 1.5652441 , 0.37471343, 1.23340754]),
#  array([0.6241877 , 0.49113929, 0.45709178, 0.43168403, 0.15976519,
#         0.3589777 , 0.62582528, 0.44314021, 0.41051701, 0.26327474,
#         0.42920285, 0.30881532]),
#  array([0.21047919, 0.58384309, 0.00306142, 0.40808762, 0.4934646 ,
#         0.56298194]),
#  array([ 0.95171151, -0.31455108,  0.54848464, -2.17957179,  0.9169168 ,
#          0.08827039,  0.66496667, -0.81973159,  0.738399  , -0.01132301,
#          0.45511874,  0.08355442,  0.75310826, -0.88961117,  0.84169399,
#         -0.96547563,  0.89030843, -0.10008881,  0.72458907, -1.40658394,
#          0.81163589, -0.05425882,  0.8770187 ,  0.42019961,  0.62396637,
#          0.23078457,  0.64716235, -0.63253993,  0.47209972, -0.54585625,
#          0.63027151,  0.21487838,  0.93200476,  0.37663092,  0.30378021,
#         -0.10831437,  0.93401937, -0.07081454,  0.57113438,  0.27021961,
#          0.3582987 , -0.28970748,  0.96720137, -1.20648611,  0.41835463,
#         -0.72760339,  0.31570449, -0.34606877,  0.84005701, -0.01936206,
#          0.41855576, -0.93883279,  0.48670102, -0.29778993,  0.60970083,
#         -0.34214666,  0.61075744, -0.55323682,  0.69107294, -0.4122362 ,
#          0.7704029 , -1.00621353,  0.2828439 ,  0.1808461 ,  0.91049649,
#          0.1468931 ,  0.71164629, -0.27102533,  0.87431153, -0.90593381,
#          0.54564086,  0.12973467,  0.54308795,  0.18345894,  0.62262752,
#         -0.58653985,  0.62535809, -1.22846702,  0.69312708,  0.25109634,
#          0.62173961, -0.89738113,  0.52979607, -0.05466685])]

# %%
for i in range(K):
    clusters[i] = clusters[i].reshape(int(len(clusters[i])/2),2)

# %%
fig=plt.figure()
#plt.figure(figsize=(4, 8), dpi=80)
ax=fig.add_axes([-2,-2,2,2])
for i in range(K):
    ax.scatter(clusters[i][:,0],clusters[i][:,1], color=colors[i],marker='o')
    ax.scatter(x_res[i],y_res[i], color=colors[i],marker='P')
